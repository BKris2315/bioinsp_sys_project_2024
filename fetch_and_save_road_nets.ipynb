# %%
import osmnx as ox

# %%
# Define the city name

city_name = "Beijing, China"
city = "beijing"
# Download the road network for driving
G = ox.graph_from_place(city_name, network_type='drive')

# Convert graph to GeoDataFrames
nodes, edges = ox.graph_to_gdfs(G)

# Save nodes and edges to CSV
nodes.to_csv(f"road_nets/{city}_nodes.csv", index=False)
edges.to_csv(f"road_nets/{city}_edges.csv", index=False)

# Plot the road network
fig, ax = ox.plot_graph(G, save=True, filepath=f"imgs/{city}_road_network.png", dpi=300)
# Out:
# /home/syntaxerror/.pyenv/versions/3.12.6/lib/python3.12/site-packages/osmnx/_overpass.py:265: UserWarning: This area is 11 times your configured Overpass max query area size. It will automatically be divided up into multiple sub-queries accordingly. This may take a long time.
#   multi_poly_proj = utils_geo._consolidate_subdivide_geometry(poly_proj)
